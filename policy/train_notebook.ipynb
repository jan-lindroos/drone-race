# %% [markdown]
# # Drone Racing PPO Training
#
# This notebook trains a PPO policy for the drone racing environment using Brax.

# %%
from train import train

# %%
make_policy, params, metrics = train(
    num_timesteps=1_000_000,
    episode_length=1000,
)

# %%
print("Training complete!")
for key, value in metrics.items():
    print(f"{key}: {value}")
